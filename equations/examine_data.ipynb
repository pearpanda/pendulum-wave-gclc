# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi

# %%
l = 0.5
t = 0.7611561379763069
P = np.array([1.048355316320342, -0.0872452767139716, -7.043435728184047, -9.001215947740674, 29.778374837724584, -15.42477044952085, -0.1743984695759515])

# %%
l = []
for i, c in enumerate(P):
    l.append(f'({c} * pow(P1_mod, {i}))')
print(' + '.join(l))
# Out:
# (1.048355316320342 * pow(P1_mod, 0)) + (-0.0872452767139716 * pow(P1_mod, 1)) + (-7.043435728184047 * pow(P1_mod, 2)) + (-9.001215947740674 * pow(P1_mod, 3)) + (29.778374837724584 * pow(P1_mod, 4)) + (-15.42477044952085 * pow(P1_mod, 5)) + (-0.1743984695759515 * pow(P1_mod, 6))

# %%
x = np.linspace(0, t, 200)
y = np.polynomial.polynomial.polyval(x, P)

# %%
plt.plot(x, y)

# %%
from approx_motion import PendulumSolver

# %%
solver = PendulumSolver(degree=6)

# %%
poly = solver.solve(2.0, pi / 3)

# %%
plt.plot(solver.ode.t, solver.ode.y[0])

# %%
x = solver.ode.t
y = np.polynomial.polynomial.polyval(x, poly)

# %%
plt.plot(x, y)
plt.plot([t, t], [-1, 1])

# %%
poly
# Out:
# array([ 1.0485297 , -0.04898247, -1.72793452, -1.2005512 ,  1.93748245,
#        -0.51674432,  0.00307067])

# %%
P
# Out:
# array([  1.04835532,  -0.08724528,  -7.04343573,  -9.00121595,
#         29.77837484, -15.42477045,  -0.17439847])

# %%
np.abs(np.polynomial.polynomial.polysub(poly, P))
# Out:
# array([1.74382276e-04, 3.82628078e-02, 5.31550121e+00, 7.80066475e+00,
#        2.78408924e+01, 1.49080261e+01, 1.77469142e-01])
